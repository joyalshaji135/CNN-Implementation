# %% [markdown]
# <a href="https://colab.research.google.com/github/joyalshaji135/CNN-Implementation/blob/master/cnn_implementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import cv2
import matplotlib.pyplot as plt
import numpy as np
from skimage.transform import resize
from pandas import DataFrame

# %%
import keras
from tensorflow.keras.layers import Conv2D,MaxPooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import BatchNormalization

# %%
from PIL import Image
from skimage import io
X=[]
Y=[]
base_path='/content/drive/MyDrive/artificalinteligents'
source_path=base_path
for child in os.listdir(source_path):
  print(child)
  sub_path = os.path.join(source_path, child)
  bsub_path = os.path.join(base_path, child)
  if os.path.isdir(sub_path):
    for data_file in os.listdir(sub_path):
      Qry = Image.open(os.path.join(sub_path, data_file))
      Qry = Qry.convert("RGB")
      Qry = np.array(Qry.resize((224,224)))
      Qry = Qry.reshape([224,224,3])
      Qry = Qry[:,:,2]
      flist=np.array(Qry)
      X.append(flist)
      Y.append(child)
# Out:
# Covid
# PNEUMONIA
# NORMAL

# %%
images_arr = np.asarray(X)
images_arr = images_arr.astype('float32')
images_arr.shape
# Out:
# (818, 224, 224)

# %%
images_arr = images_arr.reshape(-1, 224,224, 1)
images_arr = images_arr / np.max(images_arr)

# %%
# Display the first two images in training data
for i in range(5):
  plt.figure(figsize = [5,5])
  curr_img = np.reshape(images_arr[i], (224,224))
  plt.imshow(curr_img, cmap='gray')
  plt.show()

# %%
from sklearn.preprocessing import LabelBinarizer
labelBinarizer = LabelBinarizer()
y=labelBinarizer.fit_transform(Y)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(images_arr,y,test_size=0.2,random_state =42,stratify=y)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Activation,Flatten

# %%
cnnModel= Sequential()
cnnModel.add(Conv2D(64, (5,5) , padding = 'same', activation="relu", input_shape=(224,224,1)))
cnnModel.add(Conv2D(64, (5,5) , padding = 'same', activation="relu"))
cnnModel.add(Conv2D(64, (5,5) , padding = 'same', activation="relu"))
cnnModel.add(MaxPooling2D((2,2)))
cnnModel.add(Conv2D(128, (5,5) , padding = 'same', activation="relu"))
cnnModel.add(Conv2D(128, (5,5) , padding = 'same', activation="relu"))
cnnModel.add(MaxPooling2D((2,2)))
cnnModel.add(Conv2D(128, (5,5) , padding = 'same', activation="relu"))
cnnModel.add(Conv2D(128, (5,5) , padding = 'same', activation="relu"))
cnnModel.add(Conv2D(128, (5,5) , padding = 'same', activation="relu"))
cnnModel.add(MaxPooling2D((2,2)))
cnnModel.add(Flatten())
cnnModel.add(Dense(100,activation="relu"))
cnnModel.add(Dense(200,activation="relu"))
cnnModel.add(Dense(3,activation="softmax"))
cnnModel.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 64)      1664
#
#  conv2d_1 (Conv2D)           (None, 224, 224, 64)      102464
#
#  conv2d_2 (Conv2D)           (None, 224, 224, 64)      102464
#
#  max_pooling2d (MaxPooling2  (None, 112, 112, 64)      0
#  D)
#
#  conv2d_3 (Conv2D)           (None, 112, 112, 128)     204928
#
#  conv2d_4 (Conv2D)           (None, 112, 112, 128)     409728
#
#  max_pooling2d_1 (MaxPoolin  (None, 56, 56, 128)       0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 56, 56, 128)       409728
#
#  conv2d_6 (Conv2D)           (None, 56, 56, 128)       409728
#
#  conv2d_7 (Conv2D)           (None, 56, 56, 128)       409728
#
#  max_pooling2d_2 (MaxPoolin  (None, 28, 28, 128)       0
#  g2D)
#
#  flatten (Flatten)           (None, 100352)            0
#
#  dense (Dense)               (None, 100)               10035300
#
#  dense_1 (Dense)             (None, 200)               20200
#
#  dense_2 (Dense)             (None, 3)                 603
#
# =================================================================
# Total params: 12106535 (46.18 MB)
# Trainable params: 12106535 (46.18 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
cnnModel.compile(optimizer='adam',loss="categorical_crossentropy",metrics=["accuracy"])

# %%
cnnModel.fit(X_train,y_train,epochs=50,batch_size=128,verbose=1,validation_split=0.15)
# Out:
# Epoch 1/50
# 5/5 [==============================] - 97s 11s/step - loss: 1.3944 - accuracy: 0.3748 - val_loss: 1.0421 - val_accuracy: 0.3838
# Epoch 2/50
# 5/5 [==============================] - 9s 2s/step - loss: 1.0495 - accuracy: 0.4234 - val_loss: 1.0114 - val_accuracy: 0.4646
# Epoch 3/50
# 5/5 [==============================] - 9s 2s/step - loss: 1.0202 - accuracy: 0.4811 - val_loss: 1.0182 - val_accuracy: 0.4646
# Epoch 4/50
# 5/5 [==============================] - 9s 2s/step - loss: 1.0008 - accuracy: 0.4811 - val_loss: 0.9453 - val_accuracy: 0.6869
# Epoch 5/50
# 5/5 [==============================] - 9s 2s/step - loss: 0.8465 - accuracy: 0.7063 - val_loss: 0.8129 - val_accuracy: 0.7576
# Epoch 6/50
# 5/5 [==============================] - 8s 2s/step - loss: 0.7733 - accuracy: 0.6721 - val_loss: 0.7187 - val_accuracy: 0.7576
# Epoch 7/50
# 5/5 [==============================] - 9s 2s/step - loss: 0.7303 - accuracy: 0.7658 - val_loss: 0.5003 - val_accuracy: 0.7980
# Epoch 8/50
# 5/5 [==============================] - 9s 2s/step - loss: 0.5499 - accuracy: 0.7910 - val_loss: 0.4913 - val_accuracy: 0.8384
# Epoch 9/50
# 5/5 [==============================] - 8s 2s/step - loss: 0.4565 - accuracy: 0.8360 - val_loss: 0.4209 - val_accuracy: 0.8182
# Epoch 10/50
# 5/5 [==============================] - 9s 2s/step - loss: 0.3750 - accuracy: 0.8541 - val_loss: 0.3815 - val_accuracy: 0.8990
# Epoch 11/50
# 5/5 [==============================] - 8s 2s/step - loss: 0.3587 - accuracy: 0.8631 - val_loss: 0.4556 - val_accuracy: 0.9091
# Epoch 12/50
# 5/5 [==============================] - 9s 2s/step - loss: 0.3519 - accuracy: 0.8757 - val_loss: 0.4409 - val_accuracy: 0.8788
# Epoch 13/50
# 5/5 [==============================] - 9s 2s/step - loss: 0.3182 - accuracy: 0.8775 - val_loss: 0.4360 - val_accuracy: 0.8788
# Epoch 14/50
# 5/5 [==============================] - 8s 2s/step - loss: 0.3899 - accuracy: 0.8595 - val_loss: 0.3878 - val_accuracy: 0.8586
# Epoch 15/50
# 5/5 [==============================] - 8s 2s/step - loss: 0.2897 - accuracy: 0.8811 - val_loss: 0.3520 - val_accuracy: 0.8687
# Epoch 16/50
# 5/5 [==============================] - 8s 2s/step - loss: 0.2228 - accuracy: 0.9171 - val_loss: 0.4013 - val_accuracy: 0.9091
# Epoch 17/50
# 5/5 [==============================] - 9s 2s/step - loss: 0.1726 - accuracy: 0.9369 - val_loss: 0.2703 - val_accuracy: 0.9394
# Epoch 18/50
# 5/5 [==============================] - 9s 2s/step - loss: 0.1661 - accuracy: 0.9405 - val_loss: 0.1415 - val_accuracy: 0.9495
# Epoch 19/50
# 5/5 [==============================] - 9s 2s/step - loss: 0.1477 - accuracy: 0.9532 - val_loss: 0.3071 - val_accuracy: 0.8990
# Epoch 20/50
# 5/5 [==============================] - 9s 2s/step - loss: 0.1340 - accuracy: 0.9604 - val_loss: 0.2136 - val_accuracy: 0.9495
# Epoch 21/50
# 5/5 [==============================] - 9s 2s/step - loss: 0.1475 - accuracy: 0.9477 - val_loss: 0.2520 - val_accuracy: 0.9091
# Epoch 22/50
# 5/5 [==============================] - 8s 2s/step - loss: 0.1386 - accuracy: 0.9604 - val_loss: 0.1823 - val_accuracy: 0.9293
# Epoch 23/50
# 5/5 [==============================] - 8s 2s/step - loss: 0.1303 - accuracy: 0.9550 - val_loss: 0.1098 - val_accuracy: 0.9596
# Epoch 24/50
# 5/5 [==============================] - 8s 2s/step - loss: 0.0628 - accuracy: 0.9766 - val_loss: 0.3170 - val_accuracy: 0.9192
# Epoch 25/50
# 5/5 [==============================] - 9s 2s/step - loss: 0.0862 - accuracy: 0.9550 - val_loss: 0.1945 - val_accuracy: 0.9394
# Epoch 26/50
# 5/5 [==============================] - 8s 2s/step - loss: 0.1379 - accuracy: 0.9568 - val_loss: 0.1796 - val_accuracy: 0.9192
# Epoch 27/50
# 5/5 [==============================] - 8s 2s/step - loss: 0.0942 - accuracy: 0.9604 - val_loss: 0.1210 - val_accuracy: 0.9394
# Epoch 28/50
# 5/5 [==============================] - 8s 2s/step - loss: 0.0630 - accuracy: 0.9802 - val_loss: 0.0989 - val_accuracy: 0.9495
# Epoch 29/50
# 5/5 [==============================] - 8s 2s/step - loss: 0.0378 - accuracy: 0.9910 - val_loss: 0.1810 - val_accuracy: 0.9596
# Epoch 30/50
# 5/5 [==============================] - 8s 2s/step - loss: 0.0279 - accuracy: 0.9910 - val_loss: 0.2222 - val_accuracy: 0.9495
# Epoch 31/50
# 5/5 [==============================] - 8s 2s/step - loss: 0.0204 - accuracy: 0.9946 - val_loss: 0.2674 - val_accuracy: 0.9192
# Epoch 32/50
# 5/5 [==============================] - 9s 2s/step - loss: 0.0422 - accuracy: 0.9874 - val_loss: 0.1855 - val_accuracy: 0.9293
# Epoch 33/50
# 5/5 [==============================] - 8s 2s/step - loss: 0.0798 - accuracy: 0.9676 - val_loss: 0.2059 - val_accuracy: 0.9192
# Epoch 34/50
# 5/5 [==============================] - 8s 2s/step - loss: 0.1054 - accuracy: 0.9604 - val_loss: 0.1299 - val_accuracy: 0.9495
# Epoch 35/50
# 5/5 [==============================] - 9s 2s/step - loss: 0.0979 - accuracy: 0.9640 - val_loss: 0.1797 - val_accuracy: 0.9495
# Epoch 36/50
# 5/5 [==============================] - 8s 2s/step - loss: 0.0651 - accuracy: 0.9784 - val_loss: 0.2538 - val_accuracy: 0.9495
# Epoch 37/50
# 5/5 [==============================] - 8s 2s/step - loss: 0.0534 - accuracy: 0.9820 - val_loss: 0.1509 - val_accuracy: 0.9495
# Epoch 38/50
# 5/5 [==============================] - 8s 2s/step - loss: 0.0517 - accuracy: 0.9784 - val_loss: 0.2422 - val_accuracy: 0.9596
# Epoch 39/50
# 5/5 [==============================] - 8s 2s/step - loss: 0.0270 - accuracy: 0.9928 - val_loss: 0.2164 - val_accuracy: 0.9495
# Epoch 40/50
# 5/5 [==============================] - 8s 2s/step - loss: 0.0287 - accuracy: 0.9928 - val_loss: 0.2402 - val_accuracy: 0.9596
# Epoch 41/50
# 5/5 [==============================] - 9s 2s/step - loss: 0.0327 - accuracy: 0.9928 - val_loss: 0.1938 - val_accuracy: 0.9596
# Epoch 42/50
# 5/5 [==============================] - 9s 2s/step - loss: 0.0308 - accuracy: 0.9856 - val_loss: 0.1626 - val_accuracy: 0.9495
# Epoch 43/50
# 5/5 [==============================] - 8s 2s/step - loss: 0.0277 - accuracy: 0.9874 - val_loss: 0.2260 - val_accuracy: 0.9293
# Epoch 44/50
# 5/5 [==============================] - 8s 2s/step - loss: 0.0214 - accuracy: 0.9946 - val_loss: 0.1489 - val_accuracy: 0.9596
# Epoch 45/50
# 5/5 [==============================] - 9s 2s/step - loss: 0.0174 - accuracy: 0.9946 - val_loss: 0.1248 - val_accuracy: 0.9394
# Epoch 46/50
# 5/5 [==============================] - 9s 2s/step - loss: 0.0108 - accuracy: 0.9964 - val_loss: 0.1194 - val_accuracy: 0.9596
# Epoch 47/50
# 5/5 [==============================] - 9s 2s/step - loss: 0.0065 - accuracy: 0.9982 - val_loss: 0.1477 - val_accuracy: 0.9596
# Epoch 48/50
# 5/5 [==============================] - 8s 2s/step - loss: 0.0039 - accuracy: 0.9982 - val_loss: 0.1596 - val_accuracy: 0.9596
# Epoch 49/50
# 5/5 [==============================] - 8s 2s/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1587 - val_accuracy: 0.9495
# Epoch 50/50
# 5/5 [==============================] - 9s 2s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1660 - val_accuracy: 0.9495

# %%
testLoss, testAccuracy = cnnModel.evaluate(X_test,y_test)
# Out:
# 6/6 [==============================] - 6s 276ms/step - loss: 0.3285 - accuracy: 0.9451

# %%
print("Test Accuracy =", testAccuracy)
# Out:
# Test Accuracy = 0.9451219439506531

# %%
image = X[10]
image = image.reshape(-1, 224,224, 1)
image = image / np.max(image)

# %%
pred = cnnModel.predict(image)
pred = labelBinarizer.inverse_transform(pred)
print(pred)
# Out:
# 1/1 [==============================] - 1s 589ms/step
# ['Covid']

# %%
cnnModel.save('cnnmodel.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from tensorflow.keras.models import load_model
model = load_model('cnnmodel.h5')
pred = model.predict(image)
pred = labelBinarizer.inverse_transform(pred)
print(pred)
# Out:
# 1/1 [==============================] - 0s 116ms/step
# ['Covid']
